# %% [markdown]
# <a href="https://colab.research.google.com/github/vybraaaxlyntaz207/Tugas-DataMining/blob/main/kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv('01-31-03-2023-WARDAH.csv')
dataset.keys()
# Out:
# Index(['Jumlah', 'Harga'], dtype='object')

# %%
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#    Jumlah  Harga
# 0       1     59
# 1       1     23
# 2       4    112
# 3       1     75
# 4       1     66

# %%
X = np.asarray(dataset)
print(X)
# Out:
# [[   1   59]
#  [   1   23]
#  [   4  112]
#  [   1   75]
#  [   1   66]
#  [   1  665]
#  [   1  665]
#  [   1  665]
#  [   1  665]
#  [   1   83]
#  [  20   63]
#  [   4    2]
#  [   3  201]
#  [   1   22]
#  [   4   88]
#  [   1   22]
#  [   4   88]
#  [  15   33]
#  [   7 1505]
#  [   1   83]
#  [   2    7]
#  [   2   95]
#  [   5   16]
#  [   2   64]
#  [   1   32]
#  [   3   96]
#  [   3   96]
#  [   4  141]
#  [   2    7]
#  [   2   71]
#  [   2   71]
#  [   4  108]
#  [   2   34]
#  [   5  725]
#  [   2   52]
#  [   5  125]
#  [   7  175]
#  [   4    7]
#  [   6  156]
#  [   2   35]
#  [  11  286]
#  [   1  233]
#  [   4   68]
#  [   2   52]
#  [   3   99]
#  [   1   17]
#  [   1  245]
#  [   3   87]
#  [   3   51]
#  [   5  875]
#  [   6  354]
#  [   1   47]]

# %%
plt.scatter(X[:,0], X[:,1], label='True Position')
plt.xlabel("Jumlah Terjual")
plt.ylabel("Harga")
plt.title("Grafik Penjualan")
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[  3.51111111  87.71111111]
#  [  3.         823.57142857]]

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.xlabel("Jumlah Terjual")
plt.ylabel("Harga")
plt.title("Grafik Penjualan")
plt.show()

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel("Jumlah Terjual")
plt.ylabel("Harga")
plt.title("Grafik Penjualan")
plt.show()
