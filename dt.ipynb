# %% [markdown]
# <a href="https://colab.research.google.com/github/vybraaaxlyntaz207/Tugas-DataMining/blob/main/dt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('TOYOTA2022.csv')
# preprocess data
df = df.drop_duplicates()
df = df.replace('-', 0)
df = df.drop(columns=['No', 'BAHAN BAKAR'])
df = df.fillna(0)
df = pd.get_dummies(df, columns=['TYPE MOBIL'])
df['JENIS'] = pd.Categorical(df['JENIS'])
df['JENIS'] = df['JENIS'].cat.codes
df['TOTAL'] = df['TOTAL'] / df['TOTAL'].max()

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['TOTAL']), df['TOTAL'], test_size=0.2)

# %%
# create decision tree model
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# generate the rules from the decision tree model
def rules(tree, feature_names):
    left = tree.tree_.children_left
    right = tree.tree_.children_right
    threshold = tree.tree_.threshold
    features = [feature_names[i] for i in tree.tree_.feature]

    def recurse(left, right, threshold, features, node):
        if threshold[node] != -2:
            print("if ({} <= {}):".format(features[node], threshold[node]))
            if left[node] != -1:
                recurse(left, right, threshold, features, left[node])
            print("else:  # if ({} > {})".format(features[node], threshold[node]))
            if right[node] != -1:
                recurse(left, right, threshold, features, right[node])
        else:
            print("return {}".format(tree.tree_.value[node]))

    recurse(left, right, threshold, features, 0)

# %%
rules(model, X_train.columns)
# Out:
# if (JAN <= 273.0):
# if (SEP <= 289.0):
# if (MAR <= 67.0):
# if (NOV <= 54.0):
# if (SEP <= 31.0):
# if (JUN <= 28.5):
# if (AGU <= 2.5):
# if (TYPE MOBIL_Fortuner VRZ 2.4 DSL A/T Imp 2021 <= 0.5):
# if (DES <= 40.0):
# if (MAR <= 20.5):
# if (JAN <= 0.5):
# if (OKT <= 7.0):
# if (MAR <= 7.0):
# if (FEB <= 1.0):
# if (TYPE MOBIL_New Avanza 1.3 G 2019 <= 0.5):
# if (DES <= 3.0):
# if (JENIS <= 4.5):
# if (TYPE MOBIL_New Avanza 1.3 G A/T 2019 <= 0.5):
# if (TYPE MOBIL_New Avanza 1.3 E A/T 2019 <= 0.5):
# if (TYPE MOBIL_Hilux 2.4 P/U DC E <= 0.5):
# return [[4.70123643e-05]]
# else:  # if (TYPE MOBIL_Hilux 2.4 P/U DC E > 0.5)
# return [[0.]]
# else:  # if (TYPE MOBIL_New Avanza 1.3 E A/T 2019 > 0.5)
# return [[0.]]
# else:  # if (TYPE MOBIL_New Avanza 1.3 G A/T 2019 > 0.5)
# return [[9.40247285e-05]]
# else:  # if (JENIS > 4.5)
# if (NOV <= 0.5):
# if (TYPE MOBIL_All New  Kijang Inova G AT 2015 <= 0.5):
# return [[0.]]
# else:  # if (TYPE MOBIL_All New  Kijang Inova G AT 2015 > 0.5)
# return [[4.70123643e-05]]
# else:  # if (NOV > 0.5)
# return [[4.70123643e-05]]
# else:  # if (DES > 3.0)
# return [[0.00023506]]
# else:  # if (TYPE MOBIL_New Avanza 1.3 G 2019 > 0.5)
# return [[0.00032909]]
# else:  # if (FEB > 1.0)
# if (DES <= 2.5):
# return [[0.00023506]]
# else:  # if (DES > 2.5)
# return [[0.00032909]]
# else:  # if (MAR > 7.0)
# return [[0.0007522]]
# else:  # if (OKT > 7.0)
# return [[0.00136336]]
# else:  # if (JAN > 0.5)
# if (MEI <= 0.5):
# if (JUN <= 0.5):
# if (MAR <= 0.5):
# return [[0.00023506]]
# else:  # if (MAR > 0.5)
# if (TYPE MOBIL_All New  Kijang Innova Venturer Mi 2020 <= 0.5):
# return [[0.00061116]]
# else:  # if (TYPE MOBIL_All New  Kijang Innova Venturer Mi 2020 > 0.5)
# return [[0.00065817]]
# else:  # if (JUN > 0.5)
# if (FEB <= 2.5):
# return [[0.0007522]]
# else:  # if (FEB > 2.5)
# if (SEP <= 1.0):
# return [[0.00136336]]
# else:  # if (SEP > 1.0)
# return [[0.00131635]]
# else:  # if (MEI > 0.5)
# if (JAN <= 11.5):
# if (JAN <= 4.0):
# return [[0.00141037]]
# else:  # if (JAN > 4.0)
# return [[0.00131635]]
# else:  # if (JAN > 11.5)
# return [[0.00178647]]
# else:  # if (MAR > 20.5)
# return [[0.00413709]]
# else:  # if (DES > 40.0)
# return [[0.0045602]]
# else:  # if (TYPE MOBIL_Fortuner VRZ 2.4 DSL A/T Imp 2021 > 0.5)
# return [[0.00709887]]
# else:  # if (AGU > 2.5)
# if (APR <= 20.0):
# if (JUL <= 1.0):
# return [[0.0026797]]
# else:  # if (JUL > 1.0)
# if (MAR <= 3.0):
# if (TYPE MOBIL_Land Cruiser 300 VX-R <= 0.5):
# return [[0.00648771]]
# else:  # if (TYPE MOBIL_Land Cruiser 300 VX-R > 0.5)
# return [[0.00606459]]
# else:  # if (MAR > 3.0)
# if (SEP <= 5.5):
# return [[0.0056885]]
# else:  # if (SEP > 5.5)
# return [[0.00512435]]
# else:  # if (APR > 20.0)
# if (APR <= 33.0):
# return [[0.00921442]]
# else:  # if (APR > 33.0)
# return [[0.01335151]]
# else:  # if (JUN > 28.5)
# if (NOV <= 6.0):
# if (TYPE MOBIL_Calya 1.2 E STD <= 0.5):
# return [[0.03351982]]
# else:  # if (TYPE MOBIL_Calya 1.2 E STD > 0.5)
# return [[0.02308307]]
# else:  # if (NOV > 6.0)
# if (FEB <= 58.5):
# if (JAN <= 7.0):
# return [[0.01175309]]
# else:  # if (JAN > 7.0)
# return [[0.01161205]]
# else:  # if (FEB > 58.5)
# return [[0.01494993]]
# else:  # if (SEP > 31.0)
# if (JUL <= 92.0):
# if (AGU <= 32.5):
# if (APR <= 30.5):
# if (MAR <= 17.5):
# return [[0.011424]]
# else:  # if (MAR > 17.5)
# if (NOV <= 19.0):
# return [[0.01396267]]
# else:  # if (NOV > 19.0)
# return [[0.01513798]]
# else:  # if (APR > 30.5)
# if (SEP <= 93.5):
# return [[0.01974519]]
# else:  # if (SEP > 93.5)
# return [[0.01927507]]
# else:  # if (AGU > 32.5)
# if (MEI <= 44.5):
# return [[0.03920831]]
# else:  # if (MEI > 44.5)
# if (APR <= 67.0):
# return [[0.02543369]]
# else:  # if (APR > 67.0)
# return [[0.0315453]]
# else:  # if (JUL > 92.0)
# if (JAN <= 52.5):
# if (JUL <= 270.5):
# return [[0.04423863]]
# else:  # if (JUL > 270.5)
# return [[0.04673029]]
# else:  # if (JAN > 52.5)
# return [[0.05114945]]
# else:  # if (NOV > 54.0)
# if (TYPE MOBIL_All New  Kijang Innova Zenix  V  Cvt 2.0 <= 0.5):
# if (TYPE MOBIL_All New  Kijang Innova Zenix  V  Hev  Cvt 2.0 <= 0.5):
# if (JENIS <= 4.0):
# if (OKT <= 107.0):
# return [[0.07366837]]
# else:  # if (OKT > 107.0)
# return [[0.05867143]]
# else:  # if (JENIS > 4.0)
# if (SEP <= 91.5):
# if (FEB <= 102.0):
# return [[0.05411123]]
# else:  # if (FEB > 102.0)
# return [[0.04701236]]
# else:  # if (SEP > 91.5)
# if (TYPE MOBIL_All New Camry 2.5 V <= 0.5):
# return [[0.03996051]]
# else:  # if (TYPE MOBIL_All New Camry 2.5 V > 0.5)
# return [[0.04169997]]
# else:  # if (TYPE MOBIL_All New  Kijang Innova Zenix  V  Hev  Cvt 2.0 > 0.5)
# return [[0.01697146]]
# else:  # if (TYPE MOBIL_All New  Kijang Innova Zenix  V  Cvt 2.0 > 0.5)
# return [[0.10996192]]
# else:  # if (MAR > 67.0)
# if (MAR <= 298.5):
# if (APR <= 82.5):
# if (APR <= 53.0):
# if (JUL <= 35.5):
# if (MAR <= 85.5):
# return [[0.0653942]]
# else:  # if (MAR > 85.5)
# return [[0.0707066]]
# else:  # if (JUL > 35.5)
# if (APR <= 0.5):
# return [[0.0604579]]
# else:  # if (APR > 0.5)
# return [[0.05302995]]
# else:  # if (APR > 53.0)
# return [[0.02341216]]
# else:  # if (APR > 82.5)
# if (JENIS <= 3.5):
# return [[0.08208359]]
# else:  # if (JENIS > 3.5)
# if (MEI <= 81.0):
# return [[0.11282967]]
# else:  # if (MEI > 81.0)
# return [[0.09858493]]
# else:  # if (MAR > 298.5)
# if (APR <= 370.5):
# if (DES <= 227.5):
# return [[0.11969348]]
# else:  # if (DES > 227.5)
# return [[0.11776597]]
# else:  # if (APR > 370.5)
# return [[0.17653143]]
# else:  # if (SEP > 289.0)
# if (AGU <= 771.0):
# if (OKT <= 423.5):
# if (SEP <= 538.5):
# if (NOV <= 86.5):
# return [[0.10432044]]
# else:  # if (NOV > 86.5)
# if (SEP <= 472.0):
# if (DES <= 121.0):
# return [[0.14211838]]
# else:  # if (DES > 121.0)
# return [[0.14160124]]
# else:  # if (SEP > 472.0)
# return [[0.14103709]]
# else:  # if (SEP > 538.5)
# return [[0.18123266]]
# else:  # if (OKT > 423.5)
# if (MEI <= 448.5):
# if (APR <= 298.0):
# return [[0.18579286]]
# else:  # if (APR > 298.0)
# return [[0.20483287]]
# else:  # if (MEI > 448.5)
# return [[0.22824503]]
# else:  # if (AGU > 771.0)
# if (NOV <= 526.5):
# if (NOV <= 44.5):
# return [[0.27521038]]
# else:  # if (NOV > 44.5)
# return [[0.25941423]]
# else:  # if (NOV > 526.5)
# return [[0.35470829]]
# else:  # if (JAN > 273.0)
# if (OKT <= 1444.5):
# if (JUN <= 881.5):
# if (SEP <= 804.0):
# if (FEB <= 417.5):
# if (JUL <= 176.0):
# return [[0.23929293]]
# else:  # if (JUL > 176.0)
# return [[0.2323351]]
# else:  # if (FEB > 417.5)
# if (JUN <= 480.0):
# if (JENIS <= 4.5):
# return [[0.31211509]]
# else:  # if (JENIS > 4.5)
# return [[0.31427766]]
# else:  # if (JUN > 480.0)
# return [[0.30755489]]
# else:  # if (SEP > 804.0)
# if (SEP <= 914.5):
# return [[0.36194819]]
# else:  # if (SEP > 914.5)
# return [[0.43730901]]
# else:  # if (JUN > 881.5)
# if (OKT <= 1115.5):
# if (JUN <= 2318.0):
# return [[0.66809271]]
# else:  # if (JUN > 2318.0)
# return [[0.58248319]]
# else:  # if (OKT > 1115.5)
# if (JUL <= 1186.5):
# return [[0.46810211]]
# else:  # if (JUL > 1186.5)
# return [[0.5117766]]
# else:  # if (OKT > 1444.5)
# if (AGU <= 1370.0):
# if (TYPE MOBIL_New Rush 1.5 GR Sport A/T 2021 <= 0.5):
# if (MEI <= 452.0):
# return [[0.77213107]]
# else:  # if (MEI > 452.0)
# return [[0.75882657]]
# else:  # if (TYPE MOBIL_New Rush 1.5 GR Sport A/T 2021 > 0.5)
# return [[0.7920173]]
# else:  # if (AGU > 1370.0)
# if (TYPE MOBIL_All New Avanza 1.5 G 2021 <= 0.5):
# return [[1.]]
# else:  # if (TYPE MOBIL_All New Avanza 1.5 G 2021 > 0.5)
# return [[0.958159]]

# %%
# evaluate model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,10))
plot_tree(model, filled=True, fontsize=10)
plt.show()
