# %% [markdown]
# <a href="https://colab.research.google.com/github/vybraaaxlyntaz207/Tugas-DataMining/blob/main/apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_csv("data_apriori.csv")

# %%
store_data.head()
# Out:
#    Unnamed: 0  title1 title2  support  confidence    lift
# 0           0   Apple  Bread   0.5454      0.8000  1.1000
# 1           1  Butter  Bread   0.5909      0.8125  1.1916
# 2           2    Wine  Bread   0.5909      0.8125  1.1171
# 3           3  Butter   Milk   0.5909      0.8666  1.1215
# 4           4    Wine   Milk   0.6363      0.8235  1.1323

# %%
store_data.tail()
# Out:
#     Unnamed: 0 title1  title2  support  confidence    lift
# 40          40  Apple    Wine   0.2272      0.5000  1.1000
# 41          41  Apple    Wine   0.2727      0.5000  1.1000
# 42          42  Apple    Wine   0.2272      0.5000  1.2222
# 43          43   Wine  Butter   0.2727      0.6000  1.3200
# 44          44   Wine  Butter   0.2272      0.5555  1.1111

# %%
store_data.shape
# Out:
# (45, 6)

# %%
records = []
for i in range(0,22):
    records.append([str(store_data.values[i,j])for j in range(0,6)])

# %%
association_rules = apriori(records, min_support=0.2, min_confidence=0.5, min_lift=1.1, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 1

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'0.5625', '0.409'}), support=0.22727272727272727, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.409'}), items_add=frozenset({'0.5625'}), confidence=0.7142857142857143, lift=3.1428571428571432), OrderedStatistic(items_base=frozenset({'0.5625'}), items_add=frozenset({'0.409'}), confidence=1.0, lift=3.142857142857143)])

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]

    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]

    rows = (value0, value1, value2, value3, value4)

    results.append(rows)

    label = ["title1", "title2", "support", "confidence", "lift"]

    store_suggestion = pd.DataFrame.from_records(results, columns=label)

    print(store_suggestion)
# Out:
#    title1 title2 support confidence    lift
# 0  0.5625  0.409  0.2272     0.7142  3.1428

# %%
store_suggestion.describe()
# Out:
#         title1 title2 support confidence    lift
# count        1      1       1          1       1
# unique       1      1       1          1       1
# top     0.5625  0.409  0.2272     0.7142  3.1428
# freq         1      1       1          1       1
